# %% [markdown]
# # Project - Data Cleaning
#
# ## Introduction
# In this lab, we'll make use of everything we've learned about pandas, data cleaning, and exploratory data analysis. In order to complete this lab, you'll have to import, clean, combine, reshape, and visualize data to answer questions provided, as well as your own questions!
#
# ## Objectives
# You will be able to:
# - Use different types of joins to merge DataFrames
# - Identify missing values in a dataframe using built-in methods
# - Evaluate and execute the best strategy for dealing with missing, duplicate, and erroneous values for a given dataset
# - Inspect data for duplicates or extraneous values and remove them
#
#
# ## The dataset
# In this lab, we'll work with the comprehensive [Super Heroes Dataset](https://www.kaggle.com/claudiodavi/superhero-set/data), which can be found on Kaggle!
#
#
# ## Getting Started
#
# In the cell below:
#
# * Import and alias pandas as `pd`
# * Import and alias numpy as `np`
# * Import and alias seaborn as `sns`
# * Import and alias matplotlib.pyplot as `plt`
# * Set matplotlib visualizations to display inline in the notebook

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option('display.max_columns', 500)
# Out:
# /Users/carrie/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
ls
# Out:
# CONTRIBUTING.md         heroes_information.csv  super_hero_powers.csv
# LICENSE.md              index-lab-video.ipynb
# README.md               index.ipynb

# %% [markdown]
# For this lab, our dataset is split among two different sources -- `'heroes_information.csv'` and `'super_hero_powers.csv'`.
#
# Use pandas to read in each file and store them in DataFrames in the appropriate variables below. Then, display the `.head()` of each to ensure that everything loaded correctly.

# %%
heroes_df = pd.read_csv('heroes_information.csv')
powers_df = pd.read_csv('super_hero_powers.csv')

# %%
heroes_df.head(3)
# Out:
#    Unnamed: 0        name Gender Eye color           Race Hair color  Height  \
# 0           0      A-Bomb   Male    yellow          Human    No Hair   203.0
# 1           1  Abe Sapien   Male      blue  Icthyo Sapien    No Hair   191.0
# 2           2    Abin Sur   Male      blue        Ungaran    No Hair   185.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics          -      good   441.0
# 1  Dark Horse Comics       blue      good    65.0
# 2          DC Comics        red      good    90.0

# %%
powers_df.head(3)
# Out:
#    hero_names  Agility  Accelerated Healing  Lantern Power Ring  \
# 0     3-D Man     True                False               False
# 1      A-Bomb    False                 True               False
# 2  Abe Sapien     True                 True               False
#
#    Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 0                  False            False       False    False
# 1                  False            False        True    False
# 2                  False             True        True    False
#
#    Energy Absorption  Flight  Danger Sense  Underwater breathing  \
# 0              False   False         False                 False
# 1              False   False         False                 False
# 2              False   False         False                  True
#
#    Marksmanship  Weapons Master  Power Augmentation  Animal Attributes  \
# 0         False           False               False              False
# 1         False           False               False              False
# 2          True            True               False              False
#
#    Longevity  Intelligence  Super Strength  Cryokinesis  Telepathy  \
# 0      False         False            True        False      False
# 1       True         False            True        False      False
# 2       True          True            True        False       True
#
#    Energy Armor  Energy Blasts  Duplication  Size Changing  Density Control  \
# 0         False          False        False          False            False
# 1         False          False        False          False            False
# 2         False          False        False          False            False
#
#    Stamina  Astral Travel  Audio Control  Dexterity  Omnitrix  Super Speed  \
# 0     True          False          False      False     False         True
# 1     True          False          False      False     False        False
# 2     True          False          False      False     False        False
#
#    Possession  Animal Oriented Powers  Weapon-based Powers  Electrokinesis  \
# 0       False                   False                False           False
# 1       False                   False                False           False
# 2       False                   False                False           False
#
#    Darkforce Manipulation  Death Touch  Teleportation  Enhanced Senses  \
# 0                   False        False          False            False
# 1                   False        False          False            False
# 2                   False        False          False            False
#
#    Telekinesis  Energy Beams  Magic  Hyperkinesis   Jump  Clairvoyance  \
# 0        False         False  False         False  False         False
# 1        False         False  False         False  False         False
# 2        False         False  False         False  False         False
#
#    Dimensional Travel  Power Sense  Shapeshifting  Peak Human Condition  \
# 0               False        False          False                 False
# 1               False        False          False                 False
# 2               False        False          False                 False
#
#    Immortality  Camouflage  Element Control  Phasing  Astral Projection  \
# 0        False       False            False    False              False
# 1        False        True            False    False              False
# 2         True       False            False    False              False
#
#    Electrical Transport  Fire Control  Projection  Summoning  Enhanced Memory  \
# 0                 False         False       False      False            False
# 1                 False         False       False      False            False
# 2                 False         False       False      False            False
#
#    Reflexes  Invulnerability  Energy Constructs  Force Fields  \
# 0     False            False              False         False
# 1     False            False              False         False
# 2      True            False              False         False
#
#    Self-Sustenance  Anti-Gravity  Empathy  Power Nullifier  Radiation Control  \
# 0            False         False    False            False              False
# 1             True         False    False            False              False
# 2            False         False    False            False              False
#
#    Psionic Powers  Elasticity  Substance Secretion  \
# 0           False       False                False
# 1           False       False                False
# 2           False       False                False
#
#    Elemental Transmogrification  Technopath/Cyberpath  Photographic Reflexes  \
# 0                         False                 False                  False
# 1                         False                 False                  False
# 2                         False                 False                  False
#
#    Seismic Power  Animation  Precognition  Mind Control  Fire Resistance  \
# 0          False      False         False         False            False
# 1          False      False         False         False            False
# 2          False      False         False         False            False
#
#    Power Absorption  Enhanced Hearing  Nova Force  Insanity  Hypnokinesis  \
# 0             False             False       False     False         False
# 1             False             False       False     False         False
# 2             False             False       False     False         False
#
#    Animal Control  Natural Armor  Intangibility  Enhanced Sight  \
# 0           False          False          False           False
# 1           False          False          False           False
# 2           False          False          False            True
#
#    Molecular Manipulation  Heat Generation  Adaptation  Gliding  Power Suit  \
# 0                   False            False       False    False       False
# 1                   False            False       False    False       False
# 2                   False            False       False    False       False
#
#    Mind Blast  Probability Manipulation  Gravity Control  Regeneration  \
# 0       False                     False            False         False
# 1       False                     False            False         False
# 2       False                     False            False         False
#
#    Light Control  Echolocation  Levitation  Toxin and Disease Control  Banish  \
# 0          False         False       False                      False   False
# 1          False         False       False                      False   False
# 2          False         False       False                      False   False
#
#    Energy Manipulation  Heat Resistance  Natural Weapons  Time Travel  \
# 0                False            False            False        False
# 1                False            False            False        False
# 2                False            False            False        False
#
#    Enhanced Smell  Illusions  Thirstokinesis  Hair Manipulation  Illumination  \
# 0           False      False           False              False         False
# 1           False      False           False              False         False
# 2           False      False           False              False         False
#
#    Omnipotent  Cloaking  Changing Armor  Power Cosmic  Biokinesis  \
# 0       False     False           False         False       False
# 1       False     False           False         False       False
# 2       False     False           False         False       False
#
#    Water Control  Radiation Immunity  Vision - Telescopic  \
# 0          False               False                False
# 1          False               False                False
# 2          False               False                False
#
#    Toxin and Disease Resistance  Spatial Awareness  Energy Resistance  \
# 0                         False              False              False
# 1                         False              False              False
# 2                         False              False              False
#
#    Telepathy Resistance  Molecular Combustion  Omnilingualism  \
# 0                 False                 False           False
# 1                 False                 False           False
# 2                 False                 False           False
#
#    Portal Creation  Magnetism  Mind Control Resistance  Plant Control  Sonar  \
# 0            False      False                    False          False  False
# 1            False      False                    False          False  False
# 2            False      False                    False          False  False
#
#    Sonic Scream  Time Manipulation  Enhanced Touch  Magic Resistance  \
# 0         False              False           False             False
# 1         False              False           False             False
# 2         False              False           False             False
#
#    Invisibility  Sub-Mariner  Radiation Absorption  Intuitive aptitude  \
# 0         False        False                 False               False
# 1         False        False                 False               False
# 2         False         True                 False               False
#
#    Vision - Microscopic  Melting  Wind Control  Super Breath  Wallcrawling  \
# 0                 False    False         False         False         False
# 1                 False    False         False         False         False
# 2                 False    False         False         False         False
#
#    Vision - Night  Vision - Infrared  Grim Reaping  Matter Absorption  \
# 0           False              False         False              False
# 1           False              False         False              False
# 2           False              False         False              False
#
#    The Force  Resurrection  Terrakinesis  Vision - Heat  Vitakinesis  \
# 0      False         False         False          False        False
# 1      False         False         False          False        False
# 2      False         False         False          False        False
#
#    Radar Sense  Qwardian Power Ring  Weather Control  Vision - X-Ray  \
# 0        False                False            False           False
# 1        False                False            False           False
# 2        False                False            False           False
#
#    Vision - Thermal  Web Creation  Reality Warping  Odin Force  \
# 0             False         False            False       False
# 1             False         False            False       False
# 2             False         False            False       False
#
#    Symbiote Costume  Speed Force  Phoenix Force  Molecular Dissipation  \
# 0             False        False          False                  False
# 1             False        False          False                  False
# 2             False        False          False                  False
#
#    Vision - Cryo  Omnipresent  Omniscient
# 0          False        False       False
# 1          False        False       False
# 2          False        False       False

# %% [markdown]
# It looks as if the heroes information dataset contained an index column.  We did not specify that this dataset contained an index column, because we hadn't seen it yet. Pandas does not know how to tell apart an index column from any other data, so it stored it with the column name `Unnamed: 0`.
#
# Our DataFrame provided row indices by default, so this column is not needed.  Drop it from the DataFrame in place in the cell below, and then display the head of `heroes_df` to ensure that it worked properly.

# %%
heroes_df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
heroes_df.head(3)
# Out:
#          name Gender Eye color           Race Hair color  Height  \
# 0      A-Bomb   Male    yellow          Human    No Hair   203.0
# 1  Abe Sapien   Male      blue  Icthyo Sapien    No Hair   191.0
# 2    Abin Sur   Male      blue        Ungaran    No Hair   185.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics          -      good   441.0
# 1  Dark Horse Comics       blue      good    65.0
# 2          DC Comics        red      good    90.0

# %% [markdown]
# ## Familiarize yourself with the dataset
#
# The first step in our Exploratory Data Analysis will be to get familiar with the data.  This step includes:
#
# * Understanding the dimensionality of your dataset
# * Investigating what type of data it contains, and the data types used to store it
# * Discovering how missing values are encoded, and how many there are
# * Getting a feel for what information it does and doesn't contain
#
# In the cell below, get the descriptive statistics of each DataFrame.

# %%
heroes_df.shape, powers_df.shape
# Out:
# ((734, 10), (667, 168))

# %%
heroes_df.describe()
# Out:
#            Height      Weight
# count  734.000000  732.000000
# mean   102.254087   43.855191
# std    139.624543  130.823733
# min    -99.000000  -99.000000
# 25%    -99.000000  -99.000000
# 50%    175.000000   62.000000
# 75%    185.000000   90.000000
# max    975.000000  900.000000

# %% [markdown]
# There's two numerical columns (height and weight)

# %%
heroes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 734 entries, 0 to 733
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        734 non-null    object
#  1   Gender      734 non-null    object
#  2   Eye color   734 non-null    object
#  3   Race        734 non-null    object
#  4   Hair color  734 non-null    object
#  5   Height      734 non-null    float64
#  6   Publisher   719 non-null    object
#  7   Skin color  734 non-null    object
#  8   Alignment   734 non-null    object
#  9   Weight      732 non-null    float64
# dtypes: float64(2), object(8)
# memory usage: 57.5+ KB

# %%
heroes_df.isnull().sum()
# Out:
# name           0
# Gender         0
# Eye color      0
# Race           0
# Hair color     0
# Height         0
# Publisher     15
# Skin color     0
# Alignment      0
# Weight         2
# dtype: int64

# %%
list(powers_df.columns)
# Out:
# ['hero_names',
#  'Agility',
#  'Accelerated Healing',
#  'Lantern Power Ring',
#  'Dimensional Awareness',
#  'Cold Resistance',
#  'Durability',
#  'Stealth',
#  'Energy Absorption',
#  'Flight',
#  'Danger Sense',
#  'Underwater breathing',
#  'Marksmanship',
#  'Weapons Master',
#  'Power Augmentation',
#  'Animal Attributes',
#  'Longevity',
#  'Intelligence',
#  'Super Strength',
#  'Cryokinesis',
#  'Telepathy',
#  'Energy Armor',
#  'Energy Blasts',
#  'Duplication',
#  'Size Changing',
#  'Density Control',
#  'Stamina',
#  'Astral Travel',
#  'Audio Control',
#  'Dexterity',
#  'Omnitrix',
#  'Super Speed',
#  'Possession',
#  'Animal Oriented Powers',
#  'Weapon-based Powers',
#  'Electrokinesis',
#  'Darkforce Manipulation',
#  'Death Touch',
#  'Teleportation',
#  'Enhanced Senses',
#  'Telekinesis',
#  'Energy Beams',
#  'Magic',
#  'Hyperkinesis',
#  'Jump',
#  'Clairvoyance',
#  'Dimensional Travel',
#  'Power Sense',
#  'Shapeshifting',
#  'Peak Human Condition',
#  'Immortality',
#  'Camouflage',
#  'Element Control',
#  'Phasing',
#  'Astral Projection',
#  'Electrical Transport',
#  'Fire Control',
#  'Projection',
#  'Summoning',
#  'Enhanced Memory',
#  'Reflexes',
#  'Invulnerability',
#  'Energy Constructs',
#  'Force Fields',
#  'Self-Sustenance',
#  'Anti-Gravity',
#  'Empathy',
#  'Power Nullifier',
#  'Radiation Control',
#  'Psionic Powers',
#  'Elasticity',
#  'Substance Secretion',
#  'Elemental Transmogrification',
#  'Technopath/Cyberpath',
#  'Photographic Reflexes',
#  'Seismic Power',
#  'Animation',
#  'Precognition',
#  'Mind Control',
#  'Fire Resistance',
#  'Power Absorption',
#  'Enhanced Hearing',
#  'Nova Force',
#  'Insanity',
#  'Hypnokinesis',
#  'Animal Control',
#  'Natural Armor',
#  'Intangibility',
#  'Enhanced Sight',
#  'Molecular Manipulation',
#  'Heat Generation',
#  'Adaptation',
#  'Gliding',
#  'Power Suit',
#  'Mind Blast',
#  'Probability Manipulation',
#  'Gravity Control',
#  'Regeneration',
#  'Light Control',
#  'Echolocation',
#  'Levitation',
#  'Toxin and Disease Control',
#  'Banish',
#  'Energy Manipulation',
#  'Heat Resistance',
#  'Natural Weapons',
#  'Time Travel',
#  'Enhanced Smell',
#  'Illusions',
#  'Thirstokinesis',
#  'Hair Manipulation',
#  'Illumination',
#  'Omnipotent',
#  'Cloaking',
#  'Changing Armor',
#  'Power Cosmic',
#  'Biokinesis',
#  'Water Control',
#  'Radiation Immunity',
#  'Vision - Telescopic',
#  'Toxin and Disease Resistance',
#  'Spatial Awareness',
#  'Energy Resistance',
#  'Telepathy Resistance',
#  'Molecular Combustion',
#  'Omnilingualism',
#  'Portal Creation',
#  'Magnetism',
#  'Mind Control Resistance',
#  'Plant Control',
#  'Sonar',
#  'Sonic Scream',
#  'Time Manipulation',
#  'Enhanced Touch',
#  'Magic Resistance',
#  'Invisibility',
#  'Sub-Mariner',
#  'Radiation Absorption',
#  'Intuitive aptitude',
#  'Vision - Microscopic',
#  'Melting',
#  'Wind Control',
#  'Super Breath',
#  'Wallcrawling',
#  'Vision - Night',
#  'Vision - Infrared',
#  'Grim Reaping',
#  'Matter Absorption',
#  'The Force',
#  'Resurrection',
#  'Terrakinesis',
#  'Vision - Heat',
#  'Vitakinesis',
#  'Radar Sense',
#  'Qwardian Power Ring',
#  'Weather Control',
#  'Vision - X-Ray',
#  'Vision - Thermal',
#  'Web Creation',
#  'Reality Warping',
#  'Odin Force',
#  'Symbiote Costume',
#  'Speed Force',
#  'Phoenix Force',
#  'Molecular Dissipation',
#  'Vision - Cryo',
#  'Omnipresent',
#  'Omniscient']

# %%
powers_df.describe() # most of them are booleans
# Out:
#           hero_names Agility Accelerated Healing Lantern Power Ring  \
# count            667     667                 667                667
# unique           667       2                   2                  2
# top     Alex Woolsly   False               False              False
# freq               1     425                 489                656
#
#        Dimensional Awareness Cold Resistance Durability Stealth  \
# count                    667             667        667     667
# unique                     2               2          2       2
# top                    False           False      False   False
# freq                     642             620        410     541
#
#        Energy Absorption Flight Danger Sense Underwater breathing  \
# count                667    667          667                  667
# unique                 2      2            2                    2
# top                False  False        False                False
# freq                 590    455          637                  646
#
#        Marksmanship Weapons Master Power Augmentation Animal Attributes  \
# count           667            667                667               667
# unique            2              2                  2                 2
# top           False          False              False             False
# freq            548            562                659               642
#
#        Longevity Intelligence Super Strength Cryokinesis Telepathy  \
# count        667          667            667         667       667
# unique         2            2              2           2         2
# top        False        False           True       False     False
# freq         554          509            360         648       575
#
#        Energy Armor Energy Blasts Duplication Size Changing Density Control  \
# count           667           667         667           667             667
# unique            2             2           2             2               2
# top           False         False       False         False           False
# freq            659           520         651           612             652
#
#        Stamina Astral Travel Audio Control Dexterity Omnitrix Super Speed  \
# count      667           667           667       667      667         667
# unique       2             2             2         2        2           2
# top      False         False         False     False    False       False
# freq       378           663           660       661      666         418
#
#        Possession Animal Oriented Powers Weapon-based Powers Electrokinesis  \
# count         667                    667                 667            667
# unique          2                      2                   2              2
# top         False                  False               False          False
# freq          659                    627                 609            645
#
#        Darkforce Manipulation Death Touch Teleportation Enhanced Senses  \
# count                     667         667           667             667
# unique                      2           2             2               2
# top                     False       False         False           False
# freq                      657         660           595             578
#
#        Telekinesis Energy Beams  Magic Hyperkinesis   Jump Clairvoyance  \
# count          667          667    667          667    667          667
# unique           2            2      2            2      2            2
# top          False        False  False        False  False        False
# freq           606          625    623          666    602          663
#
#        Dimensional Travel Power Sense Shapeshifting Peak Human Condition  \
# count                 667         667           667                  667
# unique                  2           2             2                    2
# top                 False       False         False                False
# freq                  644         664           601                  637
#
#        Immortality Camouflage Element Control Phasing Astral Projection  \
# count          667        667             667     667               667
# unique           2          2               2       2                 2
# top          False      False           False   False             False
# freq           598        646             659     636               638
#
#        Electrical Transport Fire Control Projection Summoning Enhanced Memory  \
# count                   667          667        667       667             667
# unique                    2            2          2         2               2
# top                   False        False      False     False           False
# freq                    666          635        665       663             642
#
#        Reflexes Invulnerability Energy Constructs Force Fields  \
# count       667             667               667          667
# unique        2               2                 2            2
# top       False           False             False        False
# freq        503             550               629          581
#
#        Self-Sustenance Anti-Gravity Empathy Power Nullifier Radiation Control  \
# count              667          667     667             667               667
# unique               2            2       2               2                 2
# top              False        False   False           False             False
# freq               630          666     648             663               660
#
#        Psionic Powers Elasticity Substance Secretion  \
# count             667        667                 667
# unique              2          2                   2
# top             False      False               False
# freq              618        656                 650
#
#        Elemental Transmogrification Technopath/Cyberpath  \
# count                           667                  667
# unique                            2                    2
# top                           False                False
# freq                            661                  644
#
#        Photographic Reflexes Seismic Power Animation Precognition  \
# count                    667           667       667          667
# unique                     2             2         2            2
# top                    False         False     False        False
# freq                     664           664       662          645
#
#        Mind Control Fire Resistance Power Absorption Enhanced Hearing  \
# count           667             667              667              667
# unique            2               2                2                2
# top           False           False            False            False
# freq            645             649              655              595
#
#        Nova Force Insanity Hypnokinesis Animal Control Natural Armor  \
# count         667      667          667            667           667
# unique          2        2            2              2             2
# top         False    False        False          False         False
# freq          665      662          644            658           631
#
#        Intangibility Enhanced Sight Molecular Manipulation Heat Generation  \
# count            667            667                    667             667
# unique             2              2                      2               2
# top            False          False                  False           False
# freq             647            642                    625             643
#
#        Adaptation Gliding Power Suit Mind Blast Probability Manipulation  \
# count         667     667        667        667                      667
# unique          2       2          2          2                        2
# top         False   False      False      False                    False
# freq          662     657        634        655                      658
#
#        Gravity Control Regeneration Light Control Echolocation Levitation  \
# count              667          667           667          667        667
# unique               2            2             2            2          2
# top              False        False         False        False      False
# freq               651          639           652          665        641
#
#        Toxin and Disease Control Banish Energy Manipulation Heat Resistance  \
# count                        667    667                 667             667
# unique                         2      2                   2               2
# top                        False  False               False           False
# freq                         657    666                 615             624
#
#        Natural Weapons Time Travel Enhanced Smell Illusions Thirstokinesis  \
# count              667         667            667       667            667
# unique               2           2              2         2              2
# top              False       False          False     False          False
# freq               609         634            635       629            666
#
#        Hair Manipulation Illumination Omnipotent Cloaking Changing Armor  \
# count                667          667        667      667            667
# unique                 2            2          2        2              2
# top                False        False      False    False          False
# freq                 666          665        660      660            666
#
#        Power Cosmic Biokinesis Water Control Radiation Immunity  \
# count           667        667           667                667
# unique            2          2             2                  2
# top           False      False         False              False
# freq            660        666           654                657
#
#        Vision - Telescopic Toxin and Disease Resistance Spatial Awareness  \
# count                  667                          667               667
# unique                   2                            2                 2
# top                  False                        False             False
# freq                   624                          619               666
#
#        Energy Resistance Telepathy Resistance Molecular Combustion  \
# count                667                  667                  667
# unique                 2                    2                    2
# top                False                False                False
# freq                 660                  634                  665
#
#        Omnilingualism Portal Creation Magnetism Mind Control Resistance  \
# count             667             667       667                     667
# unique              2               2         2                       2
# top             False           False     False                   False
# freq              646             663       656                     655
#
#        Plant Control  Sonar Sonic Scream Time Manipulation Enhanced Touch  \
# count            667    667          667               667            667
# unique             2      2            2                 2              2
# top            False  False        False             False          False
# freq             659    663          661               647            660
#
#        Magic Resistance Invisibility Sub-Mariner Radiation Absorption  \
# count               667          667         667                  667
# unique                2            2           2                    2
# top               False        False       False                False
# freq                661          645         647                  660
#
#        Intuitive aptitude Vision - Microscopic Melting Wind Control  \
# count                 667                  667     667          667
# unique                  2                    2       2            2
# top                 False                False   False        False
# freq                  666                  648     665          664
#
#        Super Breath Wallcrawling Vision - Night Vision - Infrared  \
# count           667          667            667               667
# unique            2            2              2                 2
# top           False        False          False             False
# freq            644          633            633               645
#
#        Grim Reaping Matter Absorption The Force Resurrection Terrakinesis  \
# count           667               667       667          667          667
# unique            2                 2         2            2            2
# top           False             False     False        False        False
# freq            664               656       661          652          665
#
#        Vision - Heat Vitakinesis Radar Sense Qwardian Power Ring  \
# count            667         667         667                 667
# unique             2           2           2                   2
# top            False       False       False               False
# freq             648         665         661                 665
#
#        Weather Control Vision - X-Ray Vision - Thermal Web Creation  \
# count              667            667              667          667
# unique               2              2                2            2
# top              False          False            False        False
# freq               659            644              644          653
#
#        Reality Warping Odin Force Symbiote Costume Speed Force Phoenix Force  \
# count              667        667              667         667           667
# unique               2          2                2           2             2
# top              False      False            False       False         False
# freq               651        665              658         666           666
#
#        Molecular Dissipation Vision - Cryo Omnipresent Omniscient
# count                    667           667         667        667
# unique                     2             2           2          2
# top                    False         False       False      False
# freq                     666           665         665        665

# %%
powers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Columns: 168 entries, hero_names to Omniscient
# dtypes: bool(167), object(1)
# memory usage: 114.1+ KB

# %%
powers_df.head(3) # you can see all the columns because of pd.set_option('display.max_columns', 500)
# Out:
#    hero_names  Agility  Accelerated Healing  Lantern Power Ring  \
# 0     3-D Man     True                False               False
# 1      A-Bomb    False                 True               False
# 2  Abe Sapien     True                 True               False
#
#    Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 0                  False            False       False    False
# 1                  False            False        True    False
# 2                  False             True        True    False
#
#    Energy Absorption  Flight  Danger Sense  Underwater breathing  \
# 0              False   False         False                 False
# 1              False   False         False                 False
# 2              False   False         False                  True
#
#    Marksmanship  Weapons Master  Power Augmentation  Animal Attributes  \
# 0         False           False               False              False
# 1         False           False               False              False
# 2          True            True               False              False
#
#    Longevity  Intelligence  Super Strength  Cryokinesis  Telepathy  \
# 0      False         False            True        False      False
# 1       True         False            True        False      False
# 2       True          True            True        False       True
#
#    Energy Armor  Energy Blasts  Duplication  Size Changing  Density Control  \
# 0         False          False        False          False            False
# 1         False          False        False          False            False
# 2         False          False        False          False            False
#
#    Stamina  Astral Travel  Audio Control  Dexterity  Omnitrix  Super Speed  \
# 0     True          False          False      False     False         True
# 1     True          False          False      False     False        False
# 2     True          False          False      False     False        False
#
#    Possession  Animal Oriented Powers  Weapon-based Powers  Electrokinesis  \
# 0       False                   False                False           False
# 1       False                   False                False           False
# 2       False                   False                False           False
#
#    Darkforce Manipulation  Death Touch  Teleportation  Enhanced Senses  \
# 0                   False        False          False            False
# 1                   False        False          False            False
# 2                   False        False          False            False
#
#    Telekinesis  Energy Beams  Magic  Hyperkinesis   Jump  Clairvoyance  \
# 0        False         False  False         False  False         False
# 1        False         False  False         False  False         False
# 2        False         False  False         False  False         False
#
#    Dimensional Travel  Power Sense  Shapeshifting  Peak Human Condition  \
# 0               False        False          False                 False
# 1               False        False          False                 False
# 2               False        False          False                 False
#
#    Immortality  Camouflage  Element Control  Phasing  Astral Projection  \
# 0        False       False            False    False              False
# 1        False        True            False    False              False
# 2         True       False            False    False              False
#
#    Electrical Transport  Fire Control  Projection  Summoning  Enhanced Memory  \
# 0                 False         False       False      False            False
# 1                 False         False       False      False            False
# 2                 False         False       False      False            False
#
#    Reflexes  Invulnerability  Energy Constructs  Force Fields  \
# 0     False            False              False         False
# 1     False            False              False         False
# 2      True            False              False         False
#
#    Self-Sustenance  Anti-Gravity  Empathy  Power Nullifier  Radiation Control  \
# 0            False         False    False            False              False
# 1             True         False    False            False              False
# 2            False         False    False            False              False
#
#    Psionic Powers  Elasticity  Substance Secretion  \
# 0           False       False                False
# 1           False       False                False
# 2           False       False                False
#
#    Elemental Transmogrification  Technopath/Cyberpath  Photographic Reflexes  \
# 0                         False                 False                  False
# 1                         False                 False                  False
# 2                         False                 False                  False
#
#    Seismic Power  Animation  Precognition  Mind Control  Fire Resistance  \
# 0          False      False         False         False            False
# 1          False      False         False         False            False
# 2          False      False         False         False            False
#
#    Power Absorption  Enhanced Hearing  Nova Force  Insanity  Hypnokinesis  \
# 0             False             False       False     False         False
# 1             False             False       False     False         False
# 2             False             False       False     False         False
#
#    Animal Control  Natural Armor  Intangibility  Enhanced Sight  \
# 0           False          False          False           False
# 1           False          False          False           False
# 2           False          False          False            True
#
#    Molecular Manipulation  Heat Generation  Adaptation  Gliding  Power Suit  \
# 0                   False            False       False    False       False
# 1                   False            False       False    False       False
# 2                   False            False       False    False       False
#
#    Mind Blast  Probability Manipulation  Gravity Control  Regeneration  \
# 0       False                     False            False         False
# 1       False                     False            False         False
# 2       False                     False            False         False
#
#    Light Control  Echolocation  Levitation  Toxin and Disease Control  Banish  \
# 0          False         False       False                      False   False
# 1          False         False       False                      False   False
# 2          False         False       False                      False   False
#
#    Energy Manipulation  Heat Resistance  Natural Weapons  Time Travel  \
# 0                False            False            False        False
# 1                False            False            False        False
# 2                False            False            False        False
#
#    Enhanced Smell  Illusions  Thirstokinesis  Hair Manipulation  Illumination  \
# 0           False      False           False              False         False
# 1           False      False           False              False         False
# 2           False      False           False              False         False
#
#    Omnipotent  Cloaking  Changing Armor  Power Cosmic  Biokinesis  \
# 0       False     False           False         False       False
# 1       False     False           False         False       False
# 2       False     False           False         False       False
#
#    Water Control  Radiation Immunity  Vision - Telescopic  \
# 0          False               False                False
# 1          False               False                False
# 2          False               False                False
#
#    Toxin and Disease Resistance  Spatial Awareness  Energy Resistance  \
# 0                         False              False              False
# 1                         False              False              False
# 2                         False              False              False
#
#    Telepathy Resistance  Molecular Combustion  Omnilingualism  \
# 0                 False                 False           False
# 1                 False                 False           False
# 2                 False                 False           False
#
#    Portal Creation  Magnetism  Mind Control Resistance  Plant Control  Sonar  \
# 0            False      False                    False          False  False
# 1            False      False                    False          False  False
# 2            False      False                    False          False  False
#
#    Sonic Scream  Time Manipulation  Enhanced Touch  Magic Resistance  \
# 0         False              False           False             False
# 1         False              False           False             False
# 2         False              False           False             False
#
#    Invisibility  Sub-Mariner  Radiation Absorption  Intuitive aptitude  \
# 0         False        False                 False               False
# 1         False        False                 False               False
# 2         False         True                 False               False
#
#    Vision - Microscopic  Melting  Wind Control  Super Breath  Wallcrawling  \
# 0                 False    False         False         False         False
# 1                 False    False         False         False         False
# 2                 False    False         False         False         False
#
#    Vision - Night  Vision - Infrared  Grim Reaping  Matter Absorption  \
# 0           False              False         False              False
# 1           False              False         False              False
# 2           False              False         False              False
#
#    The Force  Resurrection  Terrakinesis  Vision - Heat  Vitakinesis  \
# 0      False         False         False          False        False
# 1      False         False         False          False        False
# 2      False         False         False          False        False
#
#    Radar Sense  Qwardian Power Ring  Weather Control  Vision - X-Ray  \
# 0        False                False            False           False
# 1        False                False            False           False
# 2        False                False            False           False
#
#    Vision - Thermal  Web Creation  Reality Warping  Odin Force  \
# 0             False         False            False       False
# 1             False         False            False       False
# 2             False         False            False       False
#
#    Symbiote Costume  Speed Force  Phoenix Force  Molecular Dissipation  \
# 0             False        False          False                  False
# 1             False        False          False                  False
# 2             False        False          False                  False
#
#    Vision - Cryo  Omnipresent  Omniscient
# 0          False        False       False
# 1          False        False       False
# 2          False        False       False

# %% [markdown]
# ## Dealing with missing values
#
# Starting in the cell below, detect and deal with any missing values in either DataFrame. Then, explain your methodology for detecting and dealing with outliers in the markdown section below. Be sure to explain your strategy for dealing with missing values in numeric columns, as well as your strategy for dealing with missing values in non-numeric columns.
#
# Note that if you need to add more cells to write code in, you can do this by:
#
# **1.** Highlighting a cell and then pressing `ESC` to enter command mode.
# **2.** Press `A` to add a cell above the highlighted cell, or `B` to add a cell below the highlighted cell.
#
# Describe your strategy below this line:
# ____________________________________________________________________________________________________________________________

# %%
heroes_df.isnull().sum()
# Out:
# name           0
# Gender         0
# Eye color      0
# Race           0
# Hair color     0
# Height         0
# Publisher     15
# Skin color     0
# Alignment      0
# Weight         2
# dtype: int64

# %%
heroes_df['Publisher'].value_counts()
# Out:
# Marvel Comics        388
# DC Comics            215
# NBC - Heroes          19
# Dark Horse Comics     18
# George Lucas          14
# Image Comics          14
# HarperCollins          6
# Star Trek              6
# SyFy                   5
# Team Epic TV           5
# Icon Comics            4
# IDW Publishing         4
# ABC Studios            4
# Shueisha               4
# Wildstorm              3
# Sony Pictures          2
# Rebellion              1
# J. K. Rowling          1
# Titan Books            1
# Hanna-Barbera          1
# South Park             1
# J. R. R. Tolkien       1
# Universal Studios      1
# Microsoft              1
# Name: Publisher, dtype: int64

# %%
heroes_df.isnull().sum() / len(heroes_df)
# Out:
# name          0.000000
# Gender        0.000000
# Eye color     0.000000
# Race          0.000000
# Hair color    0.000000
# Height        0.000000
# Publisher     0.020436
# Skin color    0.000000
# Alignment     0.000000
# Weight        0.002725
# dtype: float64

# %%
heroes_df.dropna(subset = ['Publisher'], inplace = True)

# %%
heroes_df.isnull().sum()
# Out:
# name          0
# Gender        0
# Eye color     0
# Race          0
# Hair color    0
# Height        0
# Publisher     0
# Skin color    0
# Alignment     0
# Weight        0
# dtype: int64

# %%
heroes_df.shape
# Out:
# (719, 10)

# %%
powers_df.isnull().sum()
# Out:
# hero_names               0
# Agility                  0
# Accelerated Healing      0
# Lantern Power Ring       0
# Dimensional Awareness    0
#                         ..
# Phoenix Force            0
# Molecular Dissipation    0
# Vision - Cryo            0
# Omnipresent              0
# Omniscient               0
# Length: 168, dtype: int64

# %%
powers_df.isnull().sum().sum() #no missing value
# Out:
# 0

# %% [markdown]
# ## Joining, Grouping, and Aggregating
#
# In the cell below, join the two DataFrames.  Think about which sort of join you should use, as well as which columns you should join on.  Rename columns and manipulate as needed.
#
# **_HINT:_** Consider the possibility that the columns you choose to join on contain duplicate entries. If that is the case, devise a strategy to deal with the duplicates.
#
# **_HINT:_** If the join throws an error message, consider setting the column you want to join on as the index for each DataFrame.

# %%
heroes_df.head(2)
# Out:
#          name Gender Eye color           Race Hair color  Height  \
# 0      A-Bomb   Male    yellow          Human    No Hair   203.0
# 1  Abe Sapien   Male      blue  Icthyo Sapien    No Hair   191.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics          -      good   441.0
# 1  Dark Horse Comics       blue      good    65.0

# %%
powers_df.head(2)
# Out:
#   hero_names  Agility  Accelerated Healing  Lantern Power Ring  \
# 0    3-D Man     True                False               False
# 1     A-Bomb    False                 True               False
#
#    Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 0                  False            False       False    False
# 1                  False            False        True    False
#
#    Energy Absorption  Flight  Danger Sense  Underwater breathing  \
# 0              False   False         False                 False
# 1              False   False         False                 False
#
#    Marksmanship  Weapons Master  Power Augmentation  Animal Attributes  \
# 0         False           False               False              False
# 1         False           False               False              False
#
#    Longevity  Intelligence  Super Strength  Cryokinesis  Telepathy  \
# 0      False         False            True        False      False
# 1       True         False            True        False      False
#
#    Energy Armor  Energy Blasts  Duplication  Size Changing  Density Control  \
# 0         False          False        False          False            False
# 1         False          False        False          False            False
#
#    Stamina  Astral Travel  Audio Control  Dexterity  Omnitrix  Super Speed  \
# 0     True          False          False      False     False         True
# 1     True          False          False      False     False        False
#
#    Possession  Animal Oriented Powers  Weapon-based Powers  Electrokinesis  \
# 0       False                   False                False           False
# 1       False                   False                False           False
#
#    Darkforce Manipulation  Death Touch  Teleportation  Enhanced Senses  \
# 0                   False        False          False            False
# 1                   False        False          False            False
#
#    Telekinesis  Energy Beams  Magic  Hyperkinesis   Jump  Clairvoyance  \
# 0        False         False  False         False  False         False
# 1        False         False  False         False  False         False
#
#    Dimensional Travel  Power Sense  Shapeshifting  Peak Human Condition  \
# 0               False        False          False                 False
# 1               False        False          False                 False
#
#    Immortality  Camouflage  Element Control  Phasing  Astral Projection  \
# 0        False       False            False    False              False
# 1        False        True            False    False              False
#
#    Electrical Transport  Fire Control  Projection  Summoning  Enhanced Memory  \
# 0                 False         False       False      False            False
# 1                 False         False       False      False            False
#
#    Reflexes  Invulnerability  Energy Constructs  Force Fields  \
# 0     False            False              False         False
# 1     False            False              False         False
#
#    Self-Sustenance  Anti-Gravity  Empathy  Power Nullifier  Radiation Control  \
# 0            False         False    False            False              False
# 1             True         False    False            False              False
#
#    Psionic Powers  Elasticity  Substance Secretion  \
# 0           False       False                False
# 1           False       False                False
#
#    Elemental Transmogrification  Technopath/Cyberpath  Photographic Reflexes  \
# 0                         False                 False                  False
# 1                         False                 False                  False
#
#    Seismic Power  Animation  Precognition  Mind Control  Fire Resistance  \
# 0          False      False         False         False            False
# 1          False      False         False         False            False
#
#    Power Absorption  Enhanced Hearing  Nova Force  Insanity  Hypnokinesis  \
# 0             False             False       False     False         False
# 1             False             False       False     False         False
#
#    Animal Control  Natural Armor  Intangibility  Enhanced Sight  \
# 0           False          False          False           False
# 1           False          False          False           False
#
#    Molecular Manipulation  Heat Generation  Adaptation  Gliding  Power Suit  \
# 0                   False            False       False    False       False
# 1                   False            False       False    False       False
#
#    Mind Blast  Probability Manipulation  Gravity Control  Regeneration  \
# 0       False                     False            False         False
# 1       False                     False            False         False
#
#    Light Control  Echolocation  Levitation  Toxin and Disease Control  Banish  \
# 0          False         False       False                      False   False
# 1          False         False       False                      False   False
#
#    Energy Manipulation  Heat Resistance  Natural Weapons  Time Travel  \
# 0                False            False            False        False
# 1                False            False            False        False
#
#    Enhanced Smell  Illusions  Thirstokinesis  Hair Manipulation  Illumination  \
# 0           False      False           False              False         False
# 1           False      False           False              False         False
#
#    Omnipotent  Cloaking  Changing Armor  Power Cosmic  Biokinesis  \
# 0       False     False           False         False       False
# 1       False     False           False         False       False
#
#    Water Control  Radiation Immunity  Vision - Telescopic  \
# 0          False               False                False
# 1          False               False                False
#
#    Toxin and Disease Resistance  Spatial Awareness  Energy Resistance  \
# 0                         False              False              False
# 1                         False              False              False
#
#    Telepathy Resistance  Molecular Combustion  Omnilingualism  \
# 0                 False                 False           False
# 1                 False                 False           False
#
#    Portal Creation  Magnetism  Mind Control Resistance  Plant Control  Sonar  \
# 0            False      False                    False          False  False
# 1            False      False                    False          False  False
#
#    Sonic Scream  Time Manipulation  Enhanced Touch  Magic Resistance  \
# 0         False              False           False             False
# 1         False              False           False             False
#
#    Invisibility  Sub-Mariner  Radiation Absorption  Intuitive aptitude  \
# 0         False        False                 False               False
# 1         False        False                 False               False
#
#    Vision - Microscopic  Melting  Wind Control  Super Breath  Wallcrawling  \
# 0                 False    False         False         False         False
# 1                 False    False         False         False         False
#
#    Vision - Night  Vision - Infrared  Grim Reaping  Matter Absorption  \
# 0           False              False         False              False
# 1           False              False         False              False
#
#    The Force  Resurrection  Terrakinesis  Vision - Heat  Vitakinesis  \
# 0      False         False         False          False        False
# 1      False         False         False          False        False
#
#    Radar Sense  Qwardian Power Ring  Weather Control  Vision - X-Ray  \
# 0        False                False            False           False
# 1        False                False            False           False
#
#    Vision - Thermal  Web Creation  Reality Warping  Odin Force  \
# 0             False         False            False       False
# 1             False         False            False       False
#
#    Symbiote Costume  Speed Force  Phoenix Force  Molecular Dissipation  \
# 0             False        False          False                  False
# 1             False        False          False                  False
#
#    Vision - Cryo  Omnipresent  Omniscient
# 0          False        False       False
# 1          False        False       False

# %%
df = heroes_df.merge(powers_df, left_on = 'name', right_on = 'hero_names', how = 'inner')

# %% [markdown]
# In the cell below, subset male and female heroes into different dataframes. Create a scatterplot of the height and weight of each hero, with weight as the y-axis. Plot both the male and female heroes subset into each dataframe, and make the color for each point in the scatterplot correspond to the gender of the superhero.

# %%
df_male = df[df['Gender'] == 'Male']
df_female = df[df['Gender'] == 'Female']

# %%
plt.style.use('ggplot')
plt.xkcd() # the chart looks like hand writing

# %%
fig = plt.figure(figsize = (12, 8))

ax1 = plt.subplot(1, 2, 1)
plt.scatter(df_male['Height'], df_male['Weight']) #height on the x axis and weight on the y axis
ax1.set_title('Male Superhero')

ax2 = plt.subplot(1, 2, 2)
plt.scatter(df_female['Height'], df_female['Weight']) #height on the x axis and weight on the y axis
ax2.set_title('Female Superhero')
# Out:
# Text(0.5, 1.0, 'Female Superhero')

# %% [markdown]
# ## Some Initial Investigation
#
# Next, slice the DataFrame as needed and visualize the distribution of heights and weights by gender.  You should have 4 total plots.
#
# In the cell below:
#
# * Slice the DataFrame into separate DataFrames by gender
# * Complete the `show_distplot()` function.  This helper function should take in a DataFrame, a string containing the gender we want to visualize, and the column name we want to visualize by gender. The function should display a distplot visualization from seaborn of the column/gender combination.
#
# Hint: Don't forget to check the [seaborn documentation for distplot](https://seaborn.pydata.org/generated/seaborn.distplot.html) if you have questions about how to use it correctly!

# %%
def show_displot(dataframe, gender, column_name):
    sns.distplot(dataframe[column_name])
    plt.title(f'{gender} {column_name}')

# %%
# Male Height
show_displot(df_male, 'Male', 'Height')

# %%
# Male Weight
show_displot(df_male, 'Male', 'Weight')

# %%
# Female Height
show_displot(df_female, 'Female', 'Height')

# %%
# Female Weight
show_displot(df_female, 'Female', 'Weight')

# %% [markdown]
# Discuss your findings from the plots above, with respect to the distribution of height and weight by gender.  Your explanation should include a discussion of any relevant summary statistics, including mean, median, mode, and the overall shape of each distribution.
#
# Write your answer below this line:
# ____________________________________________________________________________________________________________________________

# %%
df_male.describe()
# Out:
#            Height      Weight
# count  454.000000  454.000000
# mean   119.106828   62.026432
# std    140.761914  139.670550
# min    -99.000000  -99.000000
# 25%    -99.000000  -99.000000
# 50%    183.000000   79.500000
# 75%    188.000000  101.000000
# max    975.000000  900.000000

# %%
df_female.describe()
# Out:
#            Height      Weight
# count  176.000000  176.000000
# mean   114.088068   38.193182
# std    116.008421  102.498040
# min    -99.000000  -99.000000
# 25%    161.500000   49.000000
# 50%    168.000000   55.000000
# 75%    175.000000   61.000000
# max    366.000000  630.000000

# %% [markdown]
# ### Sample Question: Most Common Powers
#
# The rest of this notebook will be left to you to investigate the dataset by formulating your own questions, and then seeking answers using pandas and numpy.  Every answer should include some sort of visualization, when appropriate. Before moving on to formulating your own questions, use the dataset to answer the following questions about superhero powers:
#
# * What are the 5 most common powers overall?
# * What are the 5 most common powers in the Marvel Universe?
# * What are the 5 most common powers in the DC Universe?

# %%
df.head()
# Out:
#           name Gender Eye color               Race Hair color  Height  \
# 0       A-Bomb   Male    yellow              Human    No Hair   203.0
# 1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair   191.0
# 2     Abin Sur   Male      blue            Ungaran    No Hair   185.0
# 3  Abomination   Male     green  Human / Radiation    No Hair   203.0
# 4      Abraxas   Male      blue      Cosmic Entity      Black   -99.0
#
#            Publisher Skin color Alignment  Weight   hero_names  Agility  \
# 0      Marvel Comics          -      good   441.0       A-Bomb    False
# 1  Dark Horse Comics       blue      good    65.0   Abe Sapien     True
# 2          DC Comics        red      good    90.0     Abin Sur    False
# 3      Marvel Comics          -       bad   441.0  Abomination    False
# 4      Marvel Comics          -       bad   -99.0      Abraxas    False
#
#    Accelerated Healing  Lantern Power Ring  Dimensional Awareness  \
# 0                 True               False                  False
# 1                 True               False                  False
# 2                False                True                  False
# 3                 True               False                  False
# 4                False               False                   True
#
#    Cold Resistance  Durability  Stealth  Energy Absorption  Flight  \
# 0            False        True    False              False   False
# 1             True        True    False              False   False
# 2            False       False    False              False   False
# 3            False       False    False              False   False
# 4            False       False    False              False    True
#
#    Danger Sense  Underwater breathing  Marksmanship  Weapons Master  \
# 0         False                 False         False           False
# 1         False                  True          True            True
# 2         False                 False         False           False
# 3         False                 False         False           False
# 4         False                 False         False           False
#
#    Power Augmentation  Animal Attributes  Longevity  Intelligence  \
# 0               False              False       True         False
# 1               False              False       True          True
# 2               False              False      False         False
# 3               False              False      False          True
# 4               False              False      False          True
#
#    Super Strength  Cryokinesis  Telepathy  Energy Armor  Energy Blasts  \
# 0            True        False      False         False          False
# 1            True        False       True         False          False
# 2           False        False      False         False          False
# 3            True        False      False         False          False
# 4            True        False      False         False          False
#
#    Duplication  Size Changing  Density Control  Stamina  Astral Travel  \
# 0        False          False            False     True          False
# 1        False          False            False     True          False
# 2        False          False            False    False          False
# 3        False          False            False     True          False
# 4        False           True            False    False          False
#
#    Audio Control  Dexterity  Omnitrix  Super Speed  Possession  \
# 0          False      False     False        False       False
# 1          False      False     False        False       False
# 2          False      False     False        False       False
# 3          False      False     False         True       False
# 4          False      False     False         True       False
#
#    Animal Oriented Powers  Weapon-based Powers  Electrokinesis  \
# 0                   False                False           False
# 1                   False                False           False
# 2                   False                False           False
# 3                   False                False           False
# 4                   False                False           False
#
#    Darkforce Manipulation  Death Touch  Teleportation  Enhanced Senses  \
# 0                   False        False          False            False
# 1                   False        False          False            False
# 2                   False        False          False            False
# 3                   False        False          False            False
# 4                   False        False           True            False
#
#    Telekinesis  Energy Beams  Magic  Hyperkinesis   Jump  Clairvoyance  \
# 0        False         False  False         False  False         False
# 1        False         False  False         False  False         False
# 2        False         False  False         False  False         False
# 3        False         False  False         False  False         False
# 4        False         False   True         False  False         False
#
#    Dimensional Travel  Power Sense  Shapeshifting  Peak Human Condition  \
# 0               False        False          False                 False
# 1               False        False          False                 False
# 2               False        False          False                 False
# 3               False        False          False                 False
# 4                True        False          False                 False
#
#    Immortality  Camouflage  Element Control  Phasing  Astral Projection  \
# 0        False        True            False    False              False
# 1         True       False            False    False              False
# 2        False       False            False    False              False
# 3        False       False            False    False              False
# 4         True       False            False    False              False
#
#    Electrical Transport  Fire Control  Projection  Summoning  Enhanced Memory  \
# 0                 False         False       False      False            False
# 1                 False         False       False      False            False
# 2                 False         False       False      False            False
# 3                 False         False       False      False            False
# 4                 False         False       False      False            False
#
#    Reflexes  Invulnerability  Energy Constructs  Force Fields  \
# 0     False            False              False         False
# 1      True            False              False         False
# 2     False            False              False         False
# 3     False             True              False         False
# 4     False             True              False         False
#
#    Self-Sustenance  Anti-Gravity  Empathy  Power Nullifier  Radiation Control  \
# 0             True         False    False            False              False
# 1            False         False    False            False              False
# 2            False         False    False            False              False
# 3            False         False    False            False              False
# 4            False         False    False            False              False
#
#    Psionic Powers  Elasticity  Substance Secretion  \
# 0           False       False                False
# 1           False       False                False
# 2           False       False                False
# 3           False       False                False
# 4           False       False                False
#
#    Elemental Transmogrification  Technopath/Cyberpath  Photographic Reflexes  \
# 0                         False                 False                  False
# 1                         False                 False                  False
# 2                         False                 False                  False
# 3                         False                 False                  False
# 4                         False                 False                  False
#
#    Seismic Power  Animation  Precognition  Mind Control  Fire Resistance  \
# 0          False      False         False         False            False
# 1          False      False         False         False            False
# 2          False      False         False         False            False
# 3          False       True         False         False            False
# 4          False      False         False         False            False
#
#    Power Absorption  Enhanced Hearing  Nova Force  Insanity  Hypnokinesis  \
# 0             False             False       False     False         False
# 1             False             False       False     False         False
# 2             False             False       False     False         False
# 3             False             False       False     False         False
# 4             False             False       False     False         False
#
#    Animal Control  Natural Armor  Intangibility  Enhanced Sight  \
# 0           False          False          False           False
# 1           False          False          False            True
# 2           False          False          False           False
# 3           False          False          False           False
# 4           False          False          False           False
#
#    Molecular Manipulation  Heat Generation  Adaptation  Gliding  Power Suit  \
# 0                   False            False       False    False       False
# 1                   False            False       False    False       False
# 2                   False            False       False    False       False
# 3                   False            False       False    False       False
# 4                    True            False       False    False       False
#
#    Mind Blast  Probability Manipulation  Gravity Control  Regeneration  \
# 0       False                     False            False         False
# 1       False                     False            False         False
# 2       False                     False            False         False
# 3       False                     False            False         False
# 4       False                     False            False         False
#
#    Light Control  Echolocation  Levitation  Toxin and Disease Control  Banish  \
# 0          False         False       False                      False   False
# 1          False         False       False                      False   False
# 2          False         False       False                      False   False
# 3          False         False       False                      False   False
# 4          False         False       False                      False   False
#
#    Energy Manipulation  Heat Resistance  Natural Weapons  Time Travel  \
# 0                False            False            False        False
# 1                False            False            False        False
# 2                False            False            False        False
# 3                False            False            False        False
# 4                 True            False            False        False
#
#    Enhanced Smell  Illusions  Thirstokinesis  Hair Manipulation  Illumination  \
# 0           False      False           False              False         False
# 1           False      False           False              False         False
# 2           False      False           False              False         False
# 3           False      False           False              False         False
# 4           False      False           False              False         False
#
#    Omnipotent  Cloaking  Changing Armor  Power Cosmic  Biokinesis  \
# 0       False     False           False         False       False
# 1       False     False           False         False       False
# 2       False     False           False         False       False
# 3       False     False           False         False       False
# 4       False     False           False          True       False
#
#    Water Control  Radiation Immunity  Vision - Telescopic  \
# 0          False               False                False
# 1          False               False                False
# 2          False               False                False
# 3          False               False                False
# 4          False               False                False
#
#    Toxin and Disease Resistance  Spatial Awareness  Energy Resistance  \
# 0                         False              False              False
# 1                         False              False              False
# 2                         False              False              False
# 3                         False              False              False
# 4                         False              False              False
#
#    Telepathy Resistance  Molecular Combustion  Omnilingualism  \
# 0                 False                 False           False
# 1                 False                 False           False
# 2                 False                 False           False
# 3                 False                 False           False
# 4                 False                 False           False
#
#    Portal Creation  Magnetism  Mind Control Resistance  Plant Control  Sonar  \
# 0            False      False                    False          False  False
# 1            False      False                    False          False  False
# 2            False      False                    False          False  False
# 3            False      False                    False          False  False
# 4            False      False                    False          False  False
#
#    Sonic Scream  Time Manipulation  Enhanced Touch  Magic Resistance  \
# 0         False              False           False             False
# 1         False              False           False             False
# 2         False              False           False             False
# 3         False              False           False             False
# 4         False              False           False             False
#
#    Invisibility  Sub-Mariner  Radiation Absorption  Intuitive aptitude  \
# 0         False        False                 False               False
# 1         False         True                 False               False
# 2         False        False                 False               False
# 3         False        False                 False               False
# 4         False        False                 False               False
#
#    Vision - Microscopic  Melting  Wind Control  Super Breath  Wallcrawling  \
# 0                 False    False         False         False         False
# 1                 False    False         False         False         False
# 2                 False    False         False         False         False
# 3                 False    False         False          True         False
# 4                 False    False         False         False         False
#
#    Vision - Night  Vision - Infrared  Grim Reaping  Matter Absorption  \
# 0           False              False         False              False
# 1           False              False         False              False
# 2           False              False         False              False
# 3           False              False         False              False
# 4           False              False         False              False
#
#    The Force  Resurrection  Terrakinesis  Vision - Heat  Vitakinesis  \
# 0      False         False         False          False        False
# 1      False         False         False          False        False
# 2      False         False         False          False        False
# 3      False         False         False          False        False
# 4      False         False         False          False        False
#
#    Radar Sense  Qwardian Power Ring  Weather Control  Vision - X-Ray  \
# 0        False                False            False           False
# 1        False                False            False           False
# 2        False                False            False           False
# 3        False                False            False           False
# 4        False                False            False           False
#
#    Vision - Thermal  Web Creation  Reality Warping  Odin Force  \
# 0             False         False            False       False
# 1             False         False            False       False
# 2             False         False            False       False
# 3             False         False            False       False
# 4             False         False            False       False
#
#    Symbiote Costume  Speed Force  Phoenix Force  Molecular Dissipation  \
# 0             False        False          False                  False
# 1             False        False          False                  False
# 2             False        False          False                  False
# 3             False        False          False                  False
# 4             False        False          False                  False
#
#    Vision - Cryo  Omnipresent  Omniscient
# 0          False        False       False
# 1          False        False       False
# 2          False        False       False
# 3          False        False       False
# 4          False        False       False

# %%
list(df.columns)[11:]
# Out:
# ['Agility',
#  'Accelerated Healing',
#  'Lantern Power Ring',
#  'Dimensional Awareness',
#  'Cold Resistance',
#  'Durability',
#  'Stealth',
#  'Energy Absorption',
#  'Flight',
#  'Danger Sense',
#  'Underwater breathing',
#  'Marksmanship',
#  'Weapons Master',
#  'Power Augmentation',
#  'Animal Attributes',
#  'Longevity',
#  'Intelligence',
#  'Super Strength',
#  'Cryokinesis',
#  'Telepathy',
#  'Energy Armor',
#  'Energy Blasts',
#  'Duplication',
#  'Size Changing',
#  'Density Control',
#  'Stamina',
#  'Astral Travel',
#  'Audio Control',
#  'Dexterity',
#  'Omnitrix',
#  'Super Speed',
#  'Possession',
#  'Animal Oriented Powers',
#  'Weapon-based Powers',
#  'Electrokinesis',
#  'Darkforce Manipulation',
#  'Death Touch',
#  'Teleportation',
#  'Enhanced Senses',
#  'Telekinesis',
#  'Energy Beams',
#  'Magic',
#  'Hyperkinesis',
#  'Jump',
#  'Clairvoyance',
#  'Dimensional Travel',
#  'Power Sense',
#  'Shapeshifting',
#  'Peak Human Condition',
#  'Immortality',
#  'Camouflage',
#  'Element Control',
#  'Phasing',
#  'Astral Projection',
#  'Electrical Transport',
#  'Fire Control',
#  'Projection',
#  'Summoning',
#  'Enhanced Memory',
#  'Reflexes',
#  'Invulnerability',
#  'Energy Constructs',
#  'Force Fields',
#  'Self-Sustenance',
#  'Anti-Gravity',
#  'Empathy',
#  'Power Nullifier',
#  'Radiation Control',
#  'Psionic Powers',
#  'Elasticity',
#  'Substance Secretion',
#  'Elemental Transmogrification',
#  'Technopath/Cyberpath',
#  'Photographic Reflexes',
#  'Seismic Power',
#  'Animation',
#  'Precognition',
#  'Mind Control',
#  'Fire Resistance',
#  'Power Absorption',
#  'Enhanced Hearing',
#  'Nova Force',
#  'Insanity',
#  'Hypnokinesis',
#  'Animal Control',
#  'Natural Armor',
#  'Intangibility',
#  'Enhanced Sight',
#  'Molecular Manipulation',
#  'Heat Generation',
#  'Adaptation',
#  'Gliding',
#  'Power Suit',
#  'Mind Blast',
#  'Probability Manipulation',
#  'Gravity Control',
#  'Regeneration',
#  'Light Control',
#  'Echolocation',
#  'Levitation',
#  'Toxin and Disease Control',
#  'Banish',
#  'Energy Manipulation',
#  'Heat Resistance',
#  'Natural Weapons',
#  'Time Travel',
#  'Enhanced Smell',
#  'Illusions',
#  'Thirstokinesis',
#  'Hair Manipulation',
#  'Illumination',
#  'Omnipotent',
#  'Cloaking',
#  'Changing Armor',
#  'Power Cosmic',
#  'Biokinesis',
#  'Water Control',
#  'Radiation Immunity',
#  'Vision - Telescopic',
#  'Toxin and Disease Resistance',
#  'Spatial Awareness',
#  'Energy Resistance',
#  'Telepathy Resistance',
#  'Molecular Combustion',
#  'Omnilingualism',
#  'Portal Creation',
#  'Magnetism',
#  'Mind Control Resistance',
#  'Plant Control',
#  'Sonar',
#  'Sonic Scream',
#  'Time Manipulation',
#  'Enhanced Touch',
#  'Magic Resistance',
#  'Invisibility',
#  'Sub-Mariner',
#  'Radiation Absorption',
#  'Intuitive aptitude',
#  'Vision - Microscopic',
#  'Melting',
#  'Wind Control',
#  'Super Breath',
#  'Wallcrawling',
#  'Vision - Night',
#  'Vision - Infrared',
#  'Grim Reaping',
#  'Matter Absorption',
#  'The Force',
#  'Resurrection',
#  'Terrakinesis',
#  'Vision - Heat',
#  'Vitakinesis',
#  'Radar Sense',
#  'Qwardian Power Ring',
#  'Weather Control',
#  'Vision - X-Ray',
#  'Vision - Thermal',
#  'Web Creation',
#  'Reality Warping',
#  'Odin Force',
#  'Symbiote Costume',
#  'Speed Force',
#  'Phoenix Force',
#  'Molecular Dissipation',
#  'Vision - Cryo',
#  'Omnipresent',
#  'Omniscient']

# %%
powers_dict = {}
for x in list(df.columns)[11:]:
    powers_dict[x] = df[x].sum()

# %%
df['Accelerated Healing'].sum() #sanity check
# Out:
# 181

# %%
powers_dict
# Out:
# {'Agility': 236,
#  'Accelerated Healing': 181,
#  'Lantern Power Ring': 11,
#  'Dimensional Awareness': 25,
#  'Cold Resistance': 49,
#  'Durability': 256,
#  'Stealth': 126,
#  'Energy Absorption': 76,
#  'Flight': 211,
#  'Danger Sense': 33,
#  'Underwater breathing': 23,
#  'Marksmanship': 119,
#  'Weapons Master': 103,
#  'Power Augmentation': 8,
#  'Animal Attributes': 26,
#  'Longevity': 114,
#  'Intelligence': 156,
#  'Super Strength': 357,
#  'Cryokinesis': 20,
#  'Telepathy': 92,
#  'Energy Armor': 8,
#  'Energy Blasts': 146,
#  'Duplication': 17,
#  'Size Changing': 55,
#  'Density Control': 15,
#  'Stamina': 286,
#  'Astral Travel': 4,
#  'Audio Control': 8,
#  'Dexterity': 6,
#  'Omnitrix': 1,
#  'Super Speed': 248,
#  'Possession': 7,
#  'Animal Oriented Powers': 41,
#  'Weapon-based Powers': 60,
#  'Electrokinesis': 20,
#  'Darkforce Manipulation': 9,
#  'Death Touch': 7,
#  'Teleportation': 70,
#  'Enhanced Senses': 91,
#  'Telekinesis': 61,
#  'Energy Beams': 41,
#  'Magic': 44,
#  'Hyperkinesis': 1,
#  'Jump': 64,
#  'Clairvoyance': 5,
#  'Dimensional Travel': 23,
#  'Power Sense': 3,
#  'Shapeshifting': 65,
#  'Peak Human Condition': 30,
#  'Immortality': 68,
#  'Camouflage': 22,
#  'Element Control': 9,
#  'Phasing': 32,
#  'Astral Projection': 29,
#  'Electrical Transport': 1,
#  'Fire Control': 32,
#  'Projection': 2,
#  'Summoning': 4,
#  'Enhanced Memory': 27,
#  'Reflexes': 169,
#  'Invulnerability': 115,
#  'Energy Constructs': 39,
#  'Force Fields': 86,
#  'Self-Sustenance': 39,
#  'Anti-Gravity': 1,
#  'Empathy': 19,
#  'Power Nullifier': 4,
#  'Radiation Control': 6,
#  'Psionic Powers': 51,
#  'Elasticity': 10,
#  'Substance Secretion': 19,
#  'Elemental Transmogrification': 6,
#  'Technopath/Cyberpath': 22,
#  'Photographic Reflexes': 3,
#  'Seismic Power': 3,
#  'Animation': 5,
#  'Precognition': 23,
#  'Mind Control': 22,
#  'Fire Resistance': 19,
#  'Power Absorption': 12,
#  'Enhanced Hearing': 68,
#  'Nova Force': 2,
#  'Insanity': 5,
#  'Hypnokinesis': 24,
#  'Animal Control': 9,
#  'Natural Armor': 34,
#  'Intangibility': 19,
#  'Enhanced Sight': 23,
#  'Molecular Manipulation': 43,
#  'Heat Generation': 27,
#  'Adaptation': 5,
#  'Gliding': 12,
#  'Power Suit': 32,
#  'Mind Blast': 12,
#  'Probability Manipulation': 9,
#  'Gravity Control': 17,
#  'Regeneration': 29,
#  'Light Control': 16,
#  'Echolocation': 2,
#  'Levitation': 26,
#  'Toxin and Disease Control': 7,
#  'Banish': 1,
#  'Energy Manipulation': 53,
#  'Heat Resistance': 45,
#  'Natural Weapons': 58,
#  'Time Travel': 32,
#  'Enhanced Smell': 29,
#  'Illusions': 38,
#  'Thirstokinesis': 0,
#  'Hair Manipulation': 1,
#  'Illumination': 2,
#  'Omnipotent': 5,
#  'Cloaking': 7,
#  'Changing Armor': 1,
#  'Power Cosmic': 6,
#  'Biokinesis': 1,
#  'Water Control': 14,
#  'Radiation Immunity': 11,
#  'Vision - Telescopic': 44,
#  'Toxin and Disease Resistance': 51,
#  'Spatial Awareness': 1,
#  'Energy Resistance': 7,
#  'Telepathy Resistance': 33,
#  'Molecular Combustion': 2,
#  'Omnilingualism': 20,
#  'Portal Creation': 4,
#  'Magnetism': 11,
#  'Mind Control Resistance': 12,
#  'Plant Control': 7,
#  'Sonar': 4,
#  'Sonic Scream': 7,
#  'Time Manipulation': 20,
#  'Enhanced Touch': 7,
#  'Magic Resistance': 7,
#  'Invisibility': 22,
#  'Sub-Mariner': 19,
#  'Radiation Absorption': 7,
#  'Intuitive aptitude': 1,
#  'Vision - Microscopic': 19,
#  'Melting': 2,
#  'Wind Control': 3,
#  'Super Breath': 23,
#  'Wallcrawling': 35,
#  'Vision - Night': 38,
#  'Vision - Infrared': 24,
#  'Grim Reaping': 3,
#  'Matter Absorption': 10,
#  'The Force': 6,
#  'Resurrection': 14,
#  'Terrakinesis': 2,
#  'Vision - Heat': 19,
#  'Vitakinesis': 2,
#  'Radar Sense': 6,
#  'Qwardian Power Ring': 2,
#  'Weather Control': 7,
#  'Vision - X-Ray': 25,
#  'Vision - Thermal': 25,
#  'Web Creation': 16,
#  'Reality Warping': 14,
#  'Odin Force': 2,
#  'Symbiote Costume': 10,
#  'Speed Force': 1,
#  'Phoenix Force': 1,
#  'Molecular Dissipation': 1,
#  'Vision - Cryo': 1,
#  'Omnipresent': 2,
#  'Omniscient': 2}

# %%
top_5_overall = sorted(powers_dict.items(), key = lambda kv: kv[1])[-5:] # sort dictionary by value python

# %%
#get first column of list of tuples python
power = [x[0] for x in top_5_overall]
count = [x[1] for x in top_5_overall]

# %%
fig = plt.figure(figsize = (12, 8))
plt.bar(x = power, height = count)
plt.title('Most Common Super Powers')
# Out:
# Text(0.5, 1.0, 'Most Common Super Powers')

# %%
df_marvel = df[df['Publisher'] == 'Marvel Comics']
df_marvel['Publisher'].value_counts() #sanity check
# Out:
# Marvel Comics    341
# Name: Publisher, dtype: int64

# %%
powers_dict_marvel = {}
for x in list(df_marvel.columns)[11:]:
    powers_dict_marvel[x] = df_marvel[x].sum()

# %%
df_dc = df[df['Publisher'] == 'DC Comics']

# %%
powers_dict_dc = {}
for x in list(df_dc.columns)[11:]:
    powers_dict_dc[x] = df_dc[x].sum()

# %%
top_5_overall_marvel = sorted(powers_dict_marvel.items(), key = lambda kv: kv[1])[-5:]
top_5_overall_dc = sorted(powers_dict_dc.items(), key = lambda kv: kv[1])[-5:]

# %%
power_marvel = [x[0] for x in top_5_overall_marvel]
count_marvel = [x[1] for x in top_5_overall_marvel]

power_dc = [x[0] for x in top_5_overall_dc]
count_dc = [x[1] for x in top_5_overall_dc]

# %%
fig = plt.figure(figsize = (12, 8))

ax1 = plt.subplot(2,1,1) #two rows, one column, the first one plot
ax1.barh(y = power_marvel, width = count_marvel)
ax1.set_title("Marvel Top 5 Super Powers")

ax2 = plt.subplot(2,1,2) #two rows, one column, the second one plot
ax2.barh(y = power_dc, width = count_dc)
ax2.set_title("DC Top 5 Super Powers")

# add space between subplots matplotlib
fig.subplots_adjust(hspace = 0.5)

# %% [markdown]
# Analyze the results you found above to answer the following question:
#
# How do the top 5 powers in the Marvel and DC universes compare?  Are they similar, or are there significant differences? How do they compare to the overall trends in the entire Superheroes dataset?
#
# Write your answer below this line:
# ____________________________________________________________________________________________________________________________

# %% [markdown]
# ### Your Own Investigation
#
# For the remainder of this lab, you'll be focusing on coming up with and answering your own question, just like we did above.  Your question should not be overly simple, and should require both descriptive statistics and data visualization to answer.  In case you're unsure of what questions to ask, some sample questions have been provided below.
#
# Pick one of the following questions to investigate and answer, or come up with one of your own!
#
# * Which powers have the highest chance of co-occurring in a hero (e.g. super strength and flight), and does this differ by gender?
# * Is there a relationship between a hero's height and weight and their powerset?
# * What is the distribution of skin colors amongst alien heroes?
#
# Explain your question below this line:
# ____________________________________________________________________________________________________________________________
#
#
#
# Some sample cells have been provided to give you room to work. If you need to create more cells, you can do this easily by:
#
# 1. Highlighting a cell and then pressing `esc` to enter command mode.
# 1. Pressing `b` to add a cell below the currently highlighted cell, or `a` to add one above it.
#
# Be sure to include thoughtful, well-labeled visualizations to back up your analysis!

# %% [markdown]
# # Which powers have the highest chance of co-occurring in a hero (e.g. super strength and flight), and does this differ by gender?

# %%
for x in list(df.columns)[11:]:
    print(x)
# Out:
# Agility
# Accelerated Healing
# Lantern Power Ring
# Dimensional Awareness
# Cold Resistance
# Durability
# Stealth
# Energy Absorption
# Flight
# Danger Sense
# Underwater breathing
# Marksmanship
# Weapons Master
# Power Augmentation
# Animal Attributes
# Longevity
# Intelligence
# Super Strength
# Cryokinesis
# Telepathy
# Energy Armor
# Energy Blasts
# Duplication
# Size Changing
# Density Control
# Stamina
# Astral Travel
# Audio Control
# Dexterity
# Omnitrix
# Super Speed
# Possession
# Animal Oriented Powers
# Weapon-based Powers
# Electrokinesis
# Darkforce Manipulation
# Death Touch
# Teleportation
# Enhanced Senses
# Telekinesis
# Energy Beams
# Magic
# Hyperkinesis
# Jump
# Clairvoyance
# Dimensional Travel
# Power Sense
# Shapeshifting
# Peak Human Condition
# Immortality
# Camouflage
# Element Control
# Phasing
# Astral Projection
# Electrical Transport
# Fire Control
# Projection
# Summoning
# Enhanced Memory
# Reflexes
# Invulnerability
# Energy Constructs
# Force Fields
# Self-Sustenance
# Anti-Gravity
# Empathy
# Power Nullifier
# Radiation Control
# Psionic Powers
# Elasticity
# Substance Secretion
# Elemental Transmogrification
# Technopath/Cyberpath
# Photographic Reflexes
# Seismic Power
# Animation
# Precognition
# Mind Control
# Fire Resistance
# Power Absorption
# Enhanced Hearing
# Nova Force
# Insanity
# Hypnokinesis
# Animal Control
# Natural Armor
# Intangibility
# Enhanced Sight
# Molecular Manipulation
# Heat Generation
# Adaptation
# Gliding
# Power Suit
# Mind Blast
# Probability Manipulation
# Gravity Control
# Regeneration
# Light Control
# Echolocation
# Levitation
# Toxin and Disease Control
# Banish
# Energy Manipulation
# Heat Resistance
# Natural Weapons
# Time Travel
# Enhanced Smell
# Illusions
# Thirstokinesis
# Hair Manipulation
# Illumination
# Omnipotent
# Cloaking
# Changing Armor
# Power Cosmic
# Biokinesis
# Water Control
# Radiation Immunity
# Vision - Telescopic
# Toxin and Disease Resistance
# Spatial Awareness
# Energy Resistance
# Telepathy Resistance
# Molecular Combustion
# Omnilingualism
# Portal Creation
# Magnetism
# Mind Control Resistance
# Plant Control
# Sonar
# Sonic Scream
# Time Manipulation
# Enhanced Touch
# Magic Resistance
# Invisibility
# Sub-Mariner
# Radiation Absorption
# Intuitive aptitude
# Vision - Microscopic
# Melting
# Wind Control
# Super Breath
# Wallcrawling
# Vision - Night
# Vision - Infrared
# Grim Reaping
# Matter Absorption
# The Force
# Resurrection
# Terrakinesis
# Vision - Heat
# Vitakinesis
# Radar Sense
# Qwardian Power Ring
# Weather Control
# Vision - X-Ray
# Vision - Thermal
# Web Creation
# Reality Warping
# Odin Force
# Symbiote Costume
# Speed Force
# Phoenix Force
# Molecular Dissipation
# Vision - Cryo
# Omnipresent
# Omniscient

# %%
df_agility = df[df['Agility'] == True]

# %%
df_agility['Accelerated Healing'].sum() / len(df_agility)
# Out:
# 0.4491525423728814

# %%
highest_percentage = 0
for x in list(df.columns)[11:]:
    if x != 'Agility':
        percent = df_agility[x].sum() / len(df_agility)
        if percent > highest_percentage:
            highest_percentage = percent
            print(x, percent)
# Out:
# Accelerated Healing 0.4491525423728814
# Durability 0.4830508474576271
# Super Strength 0.7033898305084746
# Stamina 0.7330508474576272

# %%
highest_percentage = 0
for power in list(df.columns)[11:]:
    df_filter = df[df[power] == True]
    for x in list(df.columns)[11:]:
        if x != power:
            percent = df_filter[x].sum() / len(df_filter)
            if percent > highest_percentage:
                highest_percentage = percent
                print(power, x, percent)
            if percent == 1:
                print(power, x, percent)
# Out:
# Agility Accelerated Healing 0.4491525423728814
# Agility Durability 0.4830508474576271
# Agility Super Strength 0.7033898305084746
# Agility Stamina 0.7330508474576272
# Accelerated Healing Super Strength 0.8176795580110497
# Lantern Power Ring Flight 0.8181818181818182
# Dimensional Awareness Teleportation 0.84
# Cold Resistance Durability 0.8571428571428571
# Cold Resistance Super Strength 0.8775510204081632
# Durability Super Strength 0.89453125
# Underwater breathing Super Strength 0.9130434782608695
# Astral Travel Flight 1.0
# Astral Travel Flight 1.0
# Dexterity Stamina 1.0
# Omnitrix Shapeshifting 1.0
# Death Touch Super Strength 1.0
# Hyperkinesis Marksmanship 1.0
# Hyperkinesis Spatial Awareness 1.0
# Clairvoyance Intelligence 1.0
# Clairvoyance Super Strength 1.0
# Clairvoyance Invulnerability 1.0
# Electrical Transport Super Speed 1.0
# Electrical Transport Electrokinesis 1.0
# Projection Psionic Powers 1.0
# Anti-Gravity Durability 1.0
# Anti-Gravity Longevity 1.0
# Anti-Gravity Super Strength 1.0
# Anti-Gravity Energy Blasts 1.0
# Anti-Gravity Electrokinesis 1.0
# Anti-Gravity Force Fields 1.0
# Anti-Gravity Levitation 1.0
# Anti-Gravity Time Travel 1.0
# Animation Intelligence 1.0
# Nova Force Agility 1.0
# Nova Force Accelerated Healing 1.0
# Nova Force Durability 1.0
# Nova Force Energy Absorption 1.0
# Nova Force Flight 1.0
# Nova Force Super Strength 1.0
# Nova Force Energy Blasts 1.0
# Nova Force Stamina 1.0
# Nova Force Super Speed 1.0
# Nova Force Energy Beams 1.0
# Nova Force Fire Control 1.0
# Nova Force Reflexes 1.0
# Nova Force Invulnerability 1.0
# Nova Force Fire Resistance 1.0
# Nova Force Heat Generation 1.0
# Nova Force Light Control 1.0
# Nova Force Energy Manipulation 1.0
# Nova Force Heat Resistance 1.0
# Nova Force Vision - Telescopic 1.0
# Nova Force Vision - Night 1.0
# Nova Force Vision - Infrared 1.0
# Nova Force Vision - X-Ray 1.0
# Nova Force Vision - Thermal 1.0
# Animal Control Intelligence 1.0
# Adaptation Accelerated Healing 1.0
# Adaptation Super Strength 1.0
# Adaptation Super Speed 1.0
# Echolocation Agility 1.0
# Echolocation Reflexes 1.0
# Echolocation Enhanced Hearing 1.0
# Banish Dimensional Awareness 1.0
# Banish Flight 1.0
# Banish Longevity 1.0
# Banish Telepathy 1.0
# Banish Energy Blasts 1.0
# Banish Teleportation 1.0
# Banish Telekinesis 1.0
# Banish Magic 1.0
# Banish Dimensional Travel 1.0
# Banish Phasing 1.0
# Banish Astral Projection 1.0
# Banish Summoning 1.0
# Banish Force Fields 1.0
# Banish Hypnokinesis 1.0
# Banish Intangibility 1.0
# Banish Time Travel 1.0
# Banish Illusions 1.0
# Banish Time Manipulation 1.0
# Banish Invisibility 1.0
# /Users/carrie/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in long_scalars
# Hair Manipulation Durability 1.0
# Hair Manipulation Super Strength 1.0
# Hair Manipulation Stamina 1.0
# Hair Manipulation Super Speed 1.0
# Hair Manipulation Telekinesis 1.0
# Hair Manipulation Reflexes 1.0
# Illumination Durability 1.0
# Illumination Super Speed 1.0
# Illumination Reflexes 1.0
# Illumination Molecular Manipulation 1.0
# Omnipotent Dimensional Awareness 1.0
# Omnipotent Super Strength 1.0
# Omnipotent Super Speed 1.0
# Omnipotent Immortality 1.0
# Omnipotent Invulnerability 1.0
# Omnipotent Energy Manipulation 1.0
# Omnipotent Reality Warping 1.0
# Cloaking Stealth 1.0
# Changing Armor Agility 1.0
# Changing Armor Super Strength 1.0
# Changing Armor Weapon-based Powers 1.0
# Changing Armor Reflexes 1.0
# Power Cosmic Flight 1.0
# Power Cosmic Super Strength 1.0
# Power Cosmic Super Speed 1.0
# Biokinesis Agility 1.0
# Biokinesis Accelerated Healing 1.0
# Biokinesis Energy Absorption 1.0
# Biokinesis Flight 1.0
# Biokinesis Power Augmentation 1.0
# Biokinesis Longevity 1.0
# Biokinesis Super Strength 1.0
# Biokinesis Telepathy 1.0
# Biokinesis Energy Blasts 1.0
# Biokinesis Size Changing 1.0
# Biokinesis Stamina 1.0
# Biokinesis Super Speed 1.0
# Biokinesis Teleportation 1.0
# Biokinesis Telekinesis 1.0
# Biokinesis Shapeshifting 1.0
# Biokinesis Immortality 1.0
# Biokinesis Reflexes 1.0
# Biokinesis Invulnerability 1.0
# Biokinesis Force Fields 1.0
# Biokinesis Natural Armor 1.0
# Biokinesis Molecular Manipulation 1.0
# Biokinesis Levitation 1.0
# Spatial Awareness Marksmanship 1.0
# Spatial Awareness Hyperkinesis 1.0
# Molecular Combustion Accelerated Healing 1.0
# Molecular Combustion Flight 1.0
# Magic Resistance Super Strength 1.0
# Radiation Absorption Super Strength 1.0
# Intuitive aptitude Cryokinesis 1.0
# Intuitive aptitude Telekinesis 1.0
# Intuitive aptitude Enhanced Memory 1.0
# Intuitive aptitude Radiation Control 1.0
# Intuitive aptitude Precognition 1.0
# Intuitive aptitude Enhanced Hearing 1.0
# Intuitive aptitude Melting 1.0
# Melting Enhanced Memory 1.0
# Melting Enhanced Hearing 1.0
# Grim Reaping Durability 1.0
# Grim Reaping Longevity 1.0
# Grim Reaping Super Strength 1.0
# Grim Reaping Stamina 1.0
# Grim Reaping Invulnerability 1.0
# Matter Absorption Super Strength 1.0
# The Force Agility 1.0
# The Force Telekinesis 1.0
# Terrakinesis Cryokinesis 1.0
# Terrakinesis Telepathy 1.0
# Terrakinesis Fire Control 1.0
# Terrakinesis Water Control 1.0
# Vitakinesis Accelerated Healing 1.0
# Vitakinesis Flight 1.0
# Vitakinesis Super Strength 1.0
# Vitakinesis Telepathy 1.0
# Radar Sense Stamina 1.0
# Qwardian Power Ring Durability 1.0
# Qwardian Power Ring Flight 1.0
# Qwardian Power Ring Super Strength 1.0
# Qwardian Power Ring Super Speed 1.0
# Qwardian Power Ring Energy Constructs 1.0
# Vision - X-Ray Flight 1.0
# Vision - X-Ray Super Strength 1.0
# Vision - Thermal Super Strength 1.0
# Web Creation Stamina 1.0
# Odin Force Agility 1.0
# Odin Force Accelerated Healing 1.0
# Odin Force Durability 1.0
# Odin Force Longevity 1.0
# Odin Force Super Strength 1.0
# Odin Force Stamina 1.0
# Odin Force Super Speed 1.0
# Odin Force Teleportation 1.0
# Odin Force Magic 1.0
# Odin Force Reflexes 1.0
# Odin Force Invulnerability 1.0
# Odin Force Weather Control 1.0
# Symbiote Costume Super Strength 1.0
# Speed Force Agility 1.0
# Speed Force Accelerated Healing 1.0
# Speed Force Energy Absorption 1.0
# Speed Force Flight 1.0
# Speed Force Longevity 1.0
# Speed Force Energy Blasts 1.0
# Speed Force Stamina 1.0
# Speed Force Super Speed 1.0
# Speed Force Enhanced Senses 1.0
# Speed Force Phasing 1.0
# Speed Force Reflexes 1.0
# Speed Force Energy Constructs 1.0
# Speed Force Self-Sustenance 1.0
# Speed Force Time Travel 1.0
# Phoenix Force Agility 1.0
# Phoenix Force Energy Absorption 1.0
# Phoenix Force Telepathy 1.0
# Phoenix Force Telekinesis 1.0
# Phoenix Force Immortality 1.0
# Phoenix Force Astral Projection 1.0
# Phoenix Force Fire Control 1.0
# Phoenix Force Force Fields 1.0
# Phoenix Force Psionic Powers 1.0
# Phoenix Force Mind Control 1.0
# Phoenix Force Molecular Manipulation 1.0
# Phoenix Force Mind Blast 1.0
# Phoenix Force Levitation 1.0
# Phoenix Force Energy Manipulation 1.0
# Phoenix Force Illusions 1.0
# Phoenix Force Telepathy Resistance 1.0
# Phoenix Force Resurrection 1.0
# Molecular Dissipation Accelerated Healing 1.0
# Molecular Dissipation Durability 1.0
# Molecular Dissipation Energy Absorption 1.0
# Molecular Dissipation Flight 1.0
# Molecular Dissipation Longevity 1.0
# Molecular Dissipation Intelligence 1.0
# Molecular Dissipation Super Strength 1.0
# Molecular Dissipation Energy Blasts 1.0
# Molecular Dissipation Duplication 1.0
# Molecular Dissipation Size Changing 1.0
# Molecular Dissipation Density Control 1.0
# Molecular Dissipation Super Speed 1.0
# Molecular Dissipation Teleportation 1.0
# Molecular Dissipation Telekinesis 1.0
# Molecular Dissipation Immortality 1.0
# Molecular Dissipation Phasing 1.0
# Molecular Dissipation Invulnerability 1.0
# Molecular Dissipation Energy Constructs 1.0
# Molecular Dissipation Force Fields 1.0
# Molecular Dissipation Self-Sustenance 1.0
# Molecular Dissipation Precognition 1.0
# Molecular Dissipation Intangibility 1.0
# Molecular Dissipation Molecular Manipulation 1.0
# Molecular Dissipation Energy Manipulation 1.0
# Molecular Dissipation Time Travel 1.0
# Molecular Dissipation Omnilingualism 1.0
# Molecular Dissipation Time Manipulation 1.0
# Molecular Dissipation Matter Absorption 1.0
# Vision - Cryo Agility 1.0
# Vision - Cryo Accelerated Healing 1.0
# Vision - Cryo Durability 1.0
# Vision - Cryo Energy Absorption 1.0
# Vision - Cryo Flight 1.0
# Vision - Cryo Marksmanship 1.0
# Vision - Cryo Longevity 1.0
# Vision - Cryo Super Strength 1.0
# Vision - Cryo Cryokinesis 1.0
# Vision - Cryo Stamina 1.0
# Vision - Cryo Super Speed 1.0
# Vision - Cryo Enhanced Senses 1.0
# Vision - Cryo Jump 1.0
# Vision - Cryo Invulnerability 1.0
# Vision - Cryo Self-Sustenance 1.0
# Vision - Cryo Enhanced Hearing 1.0
# Vision - Cryo Hypnokinesis 1.0
# Vision - Cryo Enhanced Sight 1.0
# Vision - Cryo Vision - Telescopic 1.0
# Vision - Cryo Vision - Microscopic 1.0
# Vision - Cryo Super Breath 1.0
# Vision - Cryo Vision - X-Ray 1.0
# Omnipresent Accelerated Healing 1.0
# Omnipresent Dimensional Awareness 1.0
# Omnipresent Energy Absorption 1.0
# Omnipresent Intelligence 1.0
# Omnipresent Super Strength 1.0
# Omnipresent Super Speed 1.0
# Omnipresent Teleportation 1.0
# Omnipresent Magic 1.0
# Omnipresent Immortality 1.0
# Omnipresent Element Control 1.0
# Omnipresent Phasing 1.0
# Omnipresent Astral Projection 1.0
# Omnipresent Invulnerability 1.0
# Omnipresent Precognition 1.0
# Omnipresent Molecular Manipulation 1.0
# Omnipresent Gravity Control 1.0
# Omnipresent Energy Manipulation 1.0
# Omnipresent Time Travel 1.0
# Omnipresent Omnipotent 1.0
# Omnipresent Time Manipulation 1.0
# Omnipresent Reality Warping 1.0
# Omnipresent Omniscient 1.0
# Omniscient Accelerated Healing 1.0
# Omniscient Dimensional Awareness 1.0
# Omniscient Energy Absorption 1.0
# Omniscient Intelligence 1.0
# Omniscient Super Strength 1.0
# Omniscient Super Speed 1.0
# Omniscient Teleportation 1.0
# Omniscient Magic 1.0
# Omniscient Immortality 1.0
# Omniscient Element Control 1.0
# Omniscient Phasing 1.0
# Omniscient Astral Projection 1.0
# Omniscient Invulnerability 1.0
# Omniscient Precognition 1.0
# Omniscient Molecular Manipulation 1.0
# Omniscient Gravity Control 1.0
# Omniscient Energy Manipulation 1.0
# Omniscient Time Travel 1.0
# Omniscient Omnipotent 1.0
# Omniscient Time Manipulation 1.0
# Omniscient Reality Warping 1.0
# Omniscient Omnipresent 1.0

# %%
highest_percentage = 0
for power in list(df.columns)[11:]:
    df_filter = df[df[power] == True]
    for x in list(df.columns)[11:]:
        if x != power:
            percent = df_filter[x].sum()
            if percent > highest_percentage:
                highest_percentage = percent
                print(power, x, percent)
# Out:
# Agility Accelerated Healing 106
# Agility Durability 114
# Agility Super Strength 166
# Agility Stamina 173
# Durability Super Strength 229

# %%
highest_percentage = 0
for power in list(df.columns)[11:]:
    df_filter = df[(df[power] == True) & (df['Gender'] == 'Male')]
    for x in list(df.columns)[11:]:
        if x != power:
            percent = df_filter[x].sum() / len(df_filter)
            if percent > highest_percentage:
                highest_percentage = percent
                print(power, x, percent)
# Out:
# Agility Accelerated Healing 0.47023809523809523
# Agility Durability 0.5178571428571429
# Agility Super Strength 0.6964285714285714
# Agility Stamina 0.7619047619047619
# Accelerated Healing Super Strength 0.7971014492753623
# Dimensional Awareness Teleportation 0.8571428571428571
# Cold Resistance Durability 0.9166666666666666
# Cold Resistance Super Strength 0.9444444444444444
# Astral Travel Flight 1.0
# /Users/carrie/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in long_scalars

# %%
highest_percentage = 0
for power in list(df.columns)[11:]:
    df_filter = df[(df[power] == True) & (df['Gender'] == 'Female')]
    for x in list(df.columns)[11:]:
        if x != power:
            percent = df_filter[x].sum() / len(df_filter)
            if percent > highest_percentage:
                highest_percentage = percent
                print(power, x, percent)
# Out:
# Agility Accelerated Healing 0.359375
# Agility Durability 0.390625
# Agility Stealth 0.40625
# Agility Super Strength 0.703125
# Accelerated Healing Super Strength 0.868421052631579
# Lantern Power Ring Flight 1.0
# /Users/carrie/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in long_scalars

# %% [markdown]
# ## Summary
#
# In this lab, we demonstrated our mastery of:
# * Using all of our Pandas knowledge to date to clean the dataset and deal with null values
# * Using Queries and aggregations to group the data into interesting subsets as needed
# * Using descriptive statistics and data visualization to find answers to questions we may have about the data
